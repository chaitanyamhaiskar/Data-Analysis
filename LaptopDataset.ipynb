# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanyamhaiskar/Data-Analysis/blob/main/LaptopDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings

# %%
warnings.filterwarnings('ignore')
# warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/laptop_data.csv')

# %%
df.sample(13)
# Out:
#       Unnamed: 0  Company            TypeName  Inches  \
# 21            21   Lenovo              Gaming    15.6
# 644          644     Acer            Notebook    15.6
# 341          341   Lenovo            Notebook    15.6
# 490          490   Lenovo            Notebook    15.6
# 721          721       HP  2 in 1 Convertible    13.3
# 1193        1193    Apple           Ultrabook    12.0
# 362          362   Lenovo            Notebook    17.3
# 943          943  Toshiba            Notebook    15.6
# 196          196    Razer              Gaming    17.3
# 773          773     Dell              Gaming    15.6
# 310          310   Lenovo            Notebook    13.3
# 980          980     Dell  2 in 1 Convertible    15.6
# 339          339     Dell            Notebook    15.6
#
#                                ScreenResolution                          Cpu  \
# 21                  IPS Panel Full HD 1920x1080  Intel Core i5 7300HQ 2.5GHz
# 644                                    1366x768     Intel Core i3 6006U 2GHz
# 341                           Full HD 1920x1080  AMD A12-Series 9720P 3.6GHz
# 490                 IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 721              IPS Panel Touchscreen 1366x768   Intel Core i5 7200U 2.5GHz
# 1193         IPS Panel Retina Display 2304x1440          Intel Core M 1.1GHz
# 362                                    1600x900   Intel Core i5 7200U 2.5GHz
# 943                                    1366x768   Intel Core i5 6200U 2.3GHz
# 196         4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz
# 773                           Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 310                 IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 980   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 7500U 2.7GHz
# 339                           Full HD 1920x1080   Intel Core i5 8250U 1.6GHz
#
#        Ram                Memory                       Gpu       OpSys  \
# 21     8GB  128GB SSD +  1TB HDD   Nvidia GeForce GTX 1050  Windows 10
# 644    4GB             500GB HDD     Intel HD Graphics 520  Windows 10
# 341   12GB               2TB HDD            AMD Radeon 530  Windows 10
# 490    8GB             256GB SSD      Nvidia GeForce 940MX  Windows 10
# 721    8GB             256GB SSD     Intel HD Graphics 620  Windows 10
# 1193   8GB   256GB Flash Storage    Intel HD Graphics 5300    Mac OS X
# 362    6GB  128GB SSD +  1TB HDD  Nvidia GeForce GTX 940MX  Windows 10
# 943    8GB             256GB SSD     Intel HD Graphics 520  Windows 10
# 196   32GB               1TB SSD   Nvidia GeForce GTX 1080  Windows 10
# 773    8GB               1TB HDD   Nvidia GeForce GTX 1050  Windows 10
# 310    8GB             256GB SSD     Intel HD Graphics 620  Windows 10
# 980   12GB             512GB SSD     Intel HD Graphics 620  Windows 10
# 339    8GB             256GB SSD      Nvidia GeForce 940MX  Windows 10
#
#        Weight        Price
# 21      2.5kg   53226.7200
# 644     2.4kg   23976.0000
# 341     2.2kg   47898.7200
# 490     2.3kg   53918.8272
# 721    1.58kg   44574.0480
# 1193  0.920kg   61964.6400
# 362     2.8kg   38308.3200
# 943     2.2kg   59620.3200
# 196    3.49kg  324954.7200
# 773    2.62kg   58554.7200
# 310     1.1kg   53226.7200
# 980    2.19kg   69210.7200
# 339       2kg   60885.7200

# %%
from tabulate import tabulate
def basicDataInfo(df):
    # Display the first 5 rows of the DataFrame
    print("First 5 rows of the DataFrame:")
    print(tabulate(df.head(), headers='keys', tablefmt='rounded_outline'))
    print()  # Add a blank line for separation

    # Display the last 5 rows of the DataFrame
    print("Last 5 rows of the DataFrame:")
    print(tabulate(df.tail(), headers='keys', tablefmt='rounded_outline'))
    print()  # Add a blank line for separation

    # Display the shape of the DataFrame (number of rows and columns)
    shape_info = pd.DataFrame({"Number of Rows": [df.shape[0]], "Number of Columns": [df.shape[1]]})
    print("DataFrame shape:")
    print(tabulate(shape_info, headers='keys', tablefmt='rounded_outline'))

    #Display the null values if present:
    missing_values_info = df.isna().sum().to_frame(name="Number of Missing Values")
    print("Missing Values Summary:")
    print(tabulate(missing_values_info, headers='keys', tablefmt='rounded_outline'))

    # Display the number of duplicated rows in the DataFrame
    num_duplicates = df.duplicated().sum()
    tab = pd.DataFrame({'Duplicate Values':[num_duplicates]})
    print(tabulate(tab,headers='keys',tablefmt = 'rounded_outline'))


    # Display Nunique() values:
    nunique_vals = df.nunique().reset_index()
    nunique_vals.columns = ['Column', 'UniqueCount']
    # Display the number of unique values for each column
    print("Number of Unique Values per Column:")
    print(tabulate(nunique_vals, headers='keys', tablefmt='rounded_outline'))
    print()

    # Display Data Types()
    info = df.dtypes.reset_index()
    info.columns = ['Column','Data Type']
    print('Data types -> ')
    print(tabulate(info,headers = 'keys',tablefmt='rounded_outline'))
    print(df.dtypes.value_counts())

    # Describe function
    des = df.describe()
    print('Aggregate Values of The Data Set')
    print(tabulate(des,headers = 'keys',tablefmt = 'rounded_outline'))
    print()

# %%
basicDataInfo(df)
# Out:
# First 5 rows of the DataFrame:
# ╭────┬───────────┬────────────┬──────────┬────────────────────────────────────┬────────────────────────────┬───────┬─────────────────────┬──────────────────────────────┬─────────┬──────────┬──────────╮
# │    │ Company   │ TypeName   │   Inches │ ScreenResolution                   │ Cpu                        │ Ram   │ Memory              │ Gpu                          │ OpSys   │ Weight   │    Price │
# ├────┼───────────┼────────────┼──────────┼────────────────────────────────────┼────────────────────────────┼───────┼─────────────────────┼──────────────────────────────┼─────────┼──────────┼──────────┤
# │  0 │ Apple     │ Ultrabook  │     13.3 │ IPS Panel Retina Display 2560x1600 │ Intel Core i5 2.3GHz       │ 8GB   │ 128GB SSD           │ Intel Iris Plus Graphics 640 │ macOS   │ 1.37kg   │  71378.7 │
# │  1 │ Apple     │ Ultrabook  │     13.3 │ 1440x900                           │ Intel Core i5 1.8GHz       │ 8GB   │ 128GB Flash Storage │ Intel HD Graphics 6000       │ macOS   │ 1.34kg   │  47895.5 │
# │  2 │ HP        │ Notebook   │     15.6 │ Full HD 1920x1080                  │ Intel Core i5 7200U 2.5GHz │ 8GB   │ 256GB SSD           │ Intel HD Graphics 620        │ No OS   │ 1.86kg   │  30636   │
# │  3 │ Apple     │ Ultrabook  │     15.4 │ IPS Panel Retina Display 2880x1800 │ Intel Core i7 2.7GHz       │ 16GB  │ 512GB SSD           │ AMD Radeon Pro 455           │ macOS   │ 1.83kg   │ 135195   │
# │  4 │ Apple     │ Ultrabook  │     13.3 │ IPS Panel Retina Display 2560x1600 │ Intel Core i5 3.1GHz       │ 8GB   │ 256GB SSD           │ Intel Iris Plus Graphics 650 │ macOS   │ 1.37kg   │  96095.8 │
# ╰────┴───────────┴────────────┴──────────┴────────────────────────────────────┴────────────────────────────┴───────┴─────────────────────┴──────────────────────────────┴─────────┴──────────┴──────────╯
#
# Last 5 rows of the DataFrame:
# ╭──────┬───────────┬────────────────────┬──────────┬────────────────────────────────────────────┬──────────────────────────────────────┬───────┬────────────────────┬───────────────────────┬────────────┬──────────┬─────────╮
# │      │ Company   │ TypeName           │   Inches │ ScreenResolution                           │ Cpu                                  │ Ram   │ Memory             │ Gpu                   │ OpSys      │ Weight   │   Price │
# ├──────┼───────────┼────────────────────┼──────────┼────────────────────────────────────────────┼──────────────────────────────────────┼───────┼────────────────────┼───────────────────────┼────────────┼──────────┼─────────┤
# │ 1269 │ Asus      │ Notebook           │     15.6 │ 1366x768                                   │ Intel Core i7 6500U 2.5GHz           │ 4GB   │ 500GB HDD          │ Nvidia GeForce 920M   │ Windows 10 │ 2.2kg    │ 38378.6 │
# │ 1270 │ Lenovo    │ 2 in 1 Convertible │     14   │ IPS Panel Full HD / Touchscreen 1920x1080  │ Intel Core i7 6500U 2.5GHz           │ 4GB   │ 128GB SSD          │ Intel HD Graphics 520 │ Windows 10 │ 1.8kg    │ 33992.6 │
# │ 1271 │ Lenovo    │ 2 in 1 Convertible │     13.3 │ IPS Panel Quad HD+ / Touchscreen 3200x1800 │ Intel Core i7 6500U 2.5GHz           │ 16GB  │ 512GB SSD          │ Intel HD Graphics 520 │ Windows 10 │ 1.3kg    │ 79866.7 │
# │ 1272 │ Lenovo    │ Notebook           │     14   │ 1366x768                                   │ Intel Celeron Dual Core N3050 1.6GHz │ 2GB   │ 64GB Flash Storage │ Intel HD Graphics     │ Windows 10 │ 1.5kg    │ 12201.1 │
# │ 1273 │ HP        │ Notebook           │     15.6 │ 1366x768                                   │ Intel Core i7 6500U 2.5GHz           │ 6GB   │ 1TB HDD            │ AMD Radeon R5 M330    │ Windows 10 │ 2.19kg   │ 40705.9 │
# ╰──────┴───────────┴────────────────────┴──────────┴────────────────────────────────────────────┴──────────────────────────────────────┴───────┴────────────────────┴───────────────────────┴────────────┴──────────┴─────────╯
#
# DataFrame shape:
# ╭────┬──────────────────┬─────────────────────╮
# │    │   Number of Rows │   Number of Columns │
# ├────┼──────────────────┼─────────────────────┤
# │  0 │             1274 │                  11 │
# ╰────┴──────────────────┴─────────────────────╯
# Missing Values Summary:
# ╭──────────────────┬────────────────────────────╮
# │                  │   Number of Missing Values │
# ├──────────────────┼────────────────────────────┤
# │ Company          │                          0 │
# │ TypeName         │                          0 │
# │ Inches           │                          0 │
# │ ScreenResolution │                          0 │
# │ Cpu              │                          0 │
# │ Ram              │                          0 │
# │ Memory           │                          0 │
# │ Gpu              │                          0 │
# │ OpSys            │                          0 │
# │ Weight           │                          0 │
# │ Price            │                          0 │
# ╰──────────────────┴────────────────────────────╯
# ╭────┬────────────────────╮
# │    │   Duplicate Values │
# ├────┼────────────────────┤
# │  0 │                  0 │
# ╰────┴────────────────────╯
# Number of Unique Values per Column:
# ╭────┬──────────────────┬───────────────╮
# │    │ Column           │   UniqueCount │
# ├────┼──────────────────┼───────────────┤
# │  0 │ Company          │            19 │
# │  1 │ TypeName         │             6 │
# │  2 │ Inches           │            18 │
# │  3 │ ScreenResolution │            40 │
# │  4 │ Cpu              │           118 │
# │  5 │ Ram              │             9 │
# │  6 │ Memory           │            39 │
# │  7 │ Gpu              │           110 │
# │  8 │ OpSys            │             9 │
# │  9 │ Weight           │           179 │
# │ 10 │ Price            │           791 │
# ╰────┴──────────────────┴───────────────╯
#
# Data types ->
# ╭────┬──────────────────┬─────────────╮
# │    │ Column           │ Data Type   │
# ├────┼──────────────────┼─────────────┤
# │  0 │ Company          │ object      │
# │  1 │ TypeName         │ object      │
# │  2 │ Inches           │ float64     │
# │  3 │ ScreenResolution │ object      │
# │  4 │ Cpu              │ object      │
# │  5 │ Ram              │ object      │
# │  6 │ Memory           │ object      │
# │  7 │ Gpu              │ object      │
# │  8 │ OpSys            │ object      │
# │  9 │ Weight           │ object      │
# │ 10 │ Price            │ float64     │
# ╰────┴──────────────────┴─────────────╯
# object     9
# float64    2
# Name: count, dtype: int64
# Aggregate Values of The Data Set
# ╭───────┬────────────┬───────────╮
# │       │     Inches │     Price │
# ├───────┼────────────┼───────────┤
# │ count │ 1274       │   1274    │
# │ mean  │   15.0224  │  60503.2  │
# │ std   │    1.42994 │  37333.2  │
# │ min   │   10.1     │   9270.72 │
# │ 25%   │   14       │  32495.6  │
# │ 50%   │   15.6     │  52693.9  │
# │ 75%   │   15.6     │  79773.5  │
# │ max   │   18.4     │ 324955    │
# ╰───────┴────────────┴───────────╯

# %%
df = df.drop('Unnamed: 0',axis = 1)

# %%
df['TypeName'].unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
df = df.drop_duplicates()

# %%
df['Ram'] = df['Ram'].str.split('G',expand = True)[0]
# Out:
# <ipython-input-20-0c73756b6956>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ram'] = df['Ram'].str.split('G',expand = True)[0]

# %%
df['Ram']
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1269     4
# 1270     4
# 1271    16
# 1272     2
# 1273     6
# Name: Ram, Length: 1274, dtype: object

# %%
df[df['Memory'].str.contains('Flash Storage')]
df['Memory'] = df['Memory'].str.replace('Flash Storage','SSD')
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
df['Memory'].str.split(' ',expand = True)
df['MemoryType'] = df['Memory'].str.split(' ',expand = True)[1]
df['Memory'] = df['Memory'].str.split(' ',expand = True)[0]
# Out:
# <ipython-input-28-6d033985e6e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MemoryType'] = df['Memory'].str.split(' ',expand = True)[1]
# <ipython-input-28-6d033985e6e9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory'] = df['Memory'].str.split(' ',expand = True)[0]

# %%
df['Memory'] = df['Memory'].str.split('G',expand = True)[0]
df['Memory'] = df['Memory'].str.split('T',expand = True)[0]
# Out:
# <ipython-input-31-63336e2dd61a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory'] = df['Memory'].str.split('G',expand = True)[0]
# <ipython-input-31-63336e2dd61a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory'] = df['Memory'].str.split('T',expand = True)[0]

# %%
df[df['Memory'].str.isalnum()]
df['Memory'] = df['Memory'].str.strip()
# Out:
# <ipython-input-39-4cd93d16b3f9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory'] = df['Memory'].str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   object
#  6   Memory            1274 non-null   float64
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   object
#  10  Price             1274 non-null   float64
#  11  MemoryType        1274 non-null   object
# dtypes: float64(3), object(9)
# memory usage: 161.7+ KB

# %%
df['Memory'] = pd.to_numeric(df['Memory'],errors = 'coerce')
# Out:
# <ipython-input-44-b80145f33cef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory'] = pd.to_numeric(df['Memory'],errors = 'coerce')

# %%
# glob
# scrapping
# rqst beautiful
# desriptive analysis
# pandas profiling
# satandard scalling
# minmaxscaller
# ordinal encoding -> dummy
# onehot coder
# column Transformer
# pipeline
# simpleImputer
# function transformer
# power transf
# box-cox trans
